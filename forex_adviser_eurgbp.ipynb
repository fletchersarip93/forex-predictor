# %% [markdown]
# # FOREX Adviser
# ## EURGBP Data

# %%
import pandas as pd

df = pd.read_csv('data/EURGBP.csv', dtype={'<DTYYYYMMDD>': str,
                                          '<TIME>': str})
df = df.rename(columns={'<DTYYYYMMDD>': 'date',
                       '<TICKER>': 'ticker',
                       '<TIME>': 'time',
                       '<OPEN>': 'open',
                       '<HIGH>': 'high',
                       '<LOW>': 'low',
                       '<CLOSE>': 'close',
                       '<VOL>': 'vol'})
df['date_time'] = df['date'].str.cat(df['time'], sep='@')

# %%
df.head()
# Out:
#    ticker      date    time    open    high     low   close  vol  \
# 0  EURGBP  20010102  230100  0.6328  0.6328  0.6328  0.6328    4
# 1  EURGBP  20010102  230200  0.6328  0.6328  0.6327  0.6327    4
# 2  EURGBP  20010102  230300  0.6327  0.6327  0.6327  0.6327    4
# 3  EURGBP  20010102  230400  0.6327  0.6328  0.6327  0.6328    4
# 4  EURGBP  20010102  230500  0.6328  0.6328  0.6328  0.6328    4
#
#          date_time
# 0  20010102@230100
# 1  20010102@230200
# 2  20010102@230300
# 3  20010102@230400
# 4  20010102@230500

# %%
df.tail()
# Out:
#          ticker      date    time    open    high     low   close  vol  \
# 6859433  EURGBP  20200831  235500  0.8931  0.8931  0.8931  0.8931    4
# 6859434  EURGBP  20200831  235600  0.8930  0.8930  0.8930  0.8930    4
# 6859435  EURGBP  20200831  235700  0.8931  0.8931  0.8931  0.8931    4
# 6859436  EURGBP  20200831  235800  0.8931  0.8931  0.8931  0.8931    4
# 6859437  EURGBP  20200831  235900  0.8931  0.8931  0.8931  0.8931    4
#
#                date_time
# 6859433  20200831@235500
# 6859434  20200831@235600
# 6859435  20200831@235700
# 6859436  20200831@235800
# 6859437  20200831@235900

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6859438 entries, 0 to 6859437
# Data columns (total 9 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   ticker     6859438 non-null  object
#  1   date       6859438 non-null  object
#  2   time       6859438 non-null  object
#  3   open       6859438 non-null  float64
#  4   high       6859438 non-null  float64
#  5   low        6859438 non-null  float64
#  6   close      6859438 non-null  float64
#  7   vol        6859438 non-null  int64
#  8   date_time  6859438 non-null  object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 471.0+ MB

# %% [markdown]
# ## Prices Overall

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=df.loc[range(0, len(df.index), 1000), 'close'])

# %%
df['close'].hist()
